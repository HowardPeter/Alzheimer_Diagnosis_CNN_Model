# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from pathlib import Path
from tensorflow import keras
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from keras._tf_keras.keras.preprocessing.image import ImageDataGenerator
from keras._tf_keras.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import classification_report, confusion_matrix

# %%
BATCH_SIZE = 64
IMAGE_SIZE = [128, 128]

# %%
def get_dataset(dataset_dir):
    """Hàm này lấy dataset từ đường dẫn tệp dataset và lưu dataset dưới dạng Dataframe"""
    filepaths = list(dataset_dir.glob(r'**/*.jpg'))
    labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

    filepaths = pd.Series(filepaths, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')
    dataset_df = pd.concat([filepaths, labels], axis=1)
    
    dataset_df = dataset_df.sample(frac=1).reset_index(drop = True)
    
    return dataset_df

# %%
train_dir = Path('D:/PC/Documents/Tensorflow/Alzheimer Diagnosis CNN Model/Alzheimer Dataset/train')
train_df = get_dataset(train_dir)

train_df.head(3)
# Out:
#                                             Filepath                 Label
# 0  D:\PC\Documents\Tensorflow\Alzheimer Diagnosis...         No Impairment
# 1  D:\PC\Documents\Tensorflow\Alzheimer Diagnosis...  Very Mild Impairment
# 2  D:\PC\Documents\Tensorflow\Alzheimer Diagnosis...         No Impairment

# %%
test_df = Path('D:/PC/Documents/Tensorflow/Alzheimer Diagnosis CNN Model/Alzheimer Dataset (Augmented)/OriginalDataset')
# test_df = Path('D:/PC/Documents/Tensorflow/Alzheimer Diagnosis CNN Model/Alzheimer Dataset/test')
test_df = get_dataset(test_df)

test_df.head(3)
# Out:
#                                             Filepath                 Label
# 0  D:\PC\Documents\Tensorflow\Alzheimer Diagnosis...       Mild Impairment
# 1  D:\PC\Documents\Tensorflow\Alzheimer Diagnosis...  Very Mild Impairment
# 2  D:\PC\Documents\Tensorflow\Alzheimer Diagnosis...         No Impairment

# %%
val_df, test_df = train_test_split(test_df, test_size = 0.35, random_state = 55, stratify=test_df["Label"])

# %%
image_generator = ImageDataGenerator(rescale = 1.0/255.0)

train_images = image_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(128,128),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    seed = 5638,
    shuffle=False
)

test_images = image_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(128, 128),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    seed = 5638,
    shuffle=False
)

val_images = image_generator.flow_from_dataframe(
    dataframe=val_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(128, 128),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    seed = 5638,
    shuffle=False
)

CLASSES = list(test_images.class_indices.keys())
# Out:
# Found 10240 validated image filenames belonging to 4 classes.
# Found 2244 validated image filenames belonging to 4 classes.
# Found 4166 validated image filenames belonging to 4 classes.

# %%
model = Sequential([
    Input(shape=(*IMAGE_SIZE, 3)),

    Conv2D(16, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2), padding='same'),

    Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2), padding='same'),

    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2), padding='same'),
    
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2), padding='same'),
    
    Flatten(),
    Dropout(0.2),
    
    Dense(256, activation='relu'),
    Dropout(0.3),
    
    Dense(128, activation='relu'),
    Dropout(0.3),
    
    Dense(64, activation='relu'),
    Dropout(0.5),
    
    Dense(4, activation='softmax'),
], name = "cnn_custom_model")

model.compile(
    optimizer = Adam(learning_rate = 0.001),
    loss = tf.losses.CategoricalCrossentropy(),
    metrics = ["accuracy"]
    )

model.summary()
# Out:
# Model: "cnn_custom_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,237,220 (8.53 MB)
#  Trainable params: 2,236,740 (8.53 MB)
#  Non-trainable params: 480 (1.88 KB)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=6,
    start_from_epoch=30,
    restore_best_weights=True
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    mode='auto',
    patience=5,
    min_lr=0.0001
)

history = model.fit(train_images, epochs=100, validation_data=val_images, validation_freq=1, callbacks=[lr_scheduler, early_stopping])
# Out:
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 62s 359ms/step - accuracy: 0.3351 - loss: 1.9429 - val_accuracy: 0.5019 - val_loss: 1.0867 - learning_rate: 0.0010
# Epoch 2/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 313ms/step - accuracy: 0.5638 - loss: 0.9091 - val_accuracy: 0.3003 - val_loss: 1.2746 - learning_rate: 0.0010
# Epoch 3/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 51s 317ms/step - accuracy: 0.6044 - loss: 0.8279 - val_accuracy: 0.5190 - val_loss: 0.9799 - learning_rate: 0.0010
# Epoch 4/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 311ms/step - accuracy: 0.6520 - loss: 0.7348 - val_accuracy: 0.5067 - val_loss: 0.9144 - learning_rate: 0.0010
# Epoch 5/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 310ms/step - accuracy: 0.6564 - loss: 0.7175 - val_accuracy: 0.5972 - val_loss: 0.8015 - learning_rate: 0.0010
# Epoch 6/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 311ms/step - accuracy: 0.7065 - loss: 0.6366 - val_accuracy: 0.5166 - val_loss: 1.0533 - learning_rate: 0.0010
# Epoch 7/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 48s 302ms/step - accuracy: 0.7152 - loss: 0.6220 - val_accuracy: 0.6704 - val_loss: 0.7332 - learning_rate: 0.0010
# Epoch 8/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 313ms/step - accuracy: 0.7428 - loss: 0.5699 - val_accuracy: 0.6450 - val_loss: 0.6976 - learning_rate: 0.0010
# Epoch 9/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 46s 290ms/step - accuracy: 0.7621 - loss: 0.5357 - val_accuracy: 0.6440 - val_loss: 0.6996 - learning_rate: 0.0010
# Epoch 10/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 49s 307ms/step - accuracy: 0.7832 - loss: 0.4986 - val_accuracy: 0.6438 - val_loss: 0.6800 - learning_rate: 0.0010
# Epoch 11/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 51s 320ms/step - accuracy: 0.8100 - loss: 0.4495 - val_accuracy: 0.6668 - val_loss: 0.6749 - learning_rate: 0.0010
# Epoch 12/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 53s 329ms/step - accuracy: 0.8345 - loss: 0.3961 - val_accuracy: 0.6255 - val_loss: 0.8116 - learning_rate: 0.0010
# Epoch 13/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 52s 325ms/step - accuracy: 0.8364 - loss: 0.3955 - val_accuracy: 0.7384 - val_loss: 0.5958 - learning_rate: 0.0010
# Epoch 14/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 51s 315ms/step - accuracy: 0.8591 - loss: 0.3395 - val_accuracy: 0.7828 - val_loss: 0.4983 - learning_rate: 0.0010
# Epoch 15/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 46s 287ms/step - accuracy: 0.8729 - loss: 0.3192 - val_accuracy: 0.7799 - val_loss: 0.5059 - learning_rate: 0.0010
# Epoch 16/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 47s 291ms/step - accuracy: 0.8849 - loss: 0.2807 - val_accuracy: 0.7782 - val_loss: 0.5260 - learning_rate: 0.0010
# Epoch 17/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 45s 283ms/step - accuracy: 0.8924 - loss: 0.2773 - val_accuracy: 0.8157 - val_loss: 0.4378 - learning_rate: 0.0010
# Epoch 18/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 46s 288ms/step - accuracy: 0.8994 - loss: 0.2696 - val_accuracy: 0.7724 - val_loss: 0.4658 - learning_rate: 0.0010
# Epoch 19/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━
# Epoch 40/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 51s 320ms/step - accuracy: 0.9894 - loss: 0.0411 - val_accuracy: 0.9885 - val_loss: 0.0418 - learning_rate: 1.0000e-04
# Epoch 41/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 313ms/step - accuracy: 0.9927 - loss: 0.0315 - val_accuracy: 0.9834 - val_loss: 0.0492 - learning_rate: 1.0000e-04
# Epoch 42/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 51s 317ms/step - accuracy: 0.9917 - loss: 0.0319 - val_accuracy: 0.9846 - val_loss: 0.0467 - learning_rate: 1.0000e-04
# Epoch 43/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 53s 329ms/step - accuracy: 0.9921 - loss: 0.0296 - val_accuracy: 0.9892 - val_loss: 0.0345 - learning_rate: 1.0000e-04
# Epoch 44/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 54s 338ms/step - accuracy: 0.9921 - loss: 0.0292 - val_accuracy: 0.9894 - val_loss: 0.0364 - learning_rate: 1.0000e-04
# Epoch 45/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 52s 324ms/step - accuracy: 0.9926 - loss: 0.0286 - val_accuracy: 0.9873 - val_loss: 0.0421 - learning_rate: 1.0000e-04
# Epoch 46/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 52s 321ms/step - accuracy: 0.9947 - loss: 0.0223 - val_accuracy: 0.9851 - val_loss: 0.0431 - learning_rate: 1.0000e-04
# Epoch 47/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 310ms/step - accuracy: 0.9931 - loss: 0.0249 - val_accuracy: 0.9938 - val_loss: 0.0257 - learning_rate: 1.0000e-04
# Epoch 48/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 311ms/step - accuracy: 0.9932 - loss: 0.0266 - val_accuracy: 0.9906 - val_loss: 0.0302 - learning_rate: 1.0000e-04
# Epoch 49/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 310ms/step - accuracy: 0.9935 - loss: 0.0242 - val_accuracy: 0.9832 - val_loss: 0.0494 - learning_rate: 1.0000e-04
# Epoch 50/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 310ms/step - accuracy: 0.9963 - loss: 0.0190 - val_accuracy: 0.9887 - val_loss: 0.0306 - learning_rate: 1.0000e-04
# Epoch 51/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 50s 310ms/step - accuracy: 0.9941 - loss: 0.0214 - val_accuracy: 0.9918 - val_loss: 0.0305 - learning_rate: 1.0000e-04
# Epoch 52/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 48s 301ms/step - accuracy: 0.9935 - loss: 0.0199 - val_accuracy: 0.9794 - val_loss: 0.0655 - learning_rate: 1.0000e-04
# Epoch 53/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 52s 321ms/step - accuracy: 0.9947 - loss: 0.0207 - val_accuracy: 0.9870 - val_loss: 0.0423 - learning_rate: 1.0000e-04

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
test_scores = model.evaluate(test_images)
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
pred_labels = model.predict(test_images)

def roundoff(arr):
    """Hàm này chuyển giá trị lớn nhất trong mảng truyền vào = 1, các giá trị còn lại = 0"""
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

pred = np.argmax(pred_labels,axis=1)

print(classification_report(test_images.classes,pred,target_names=CLASSES))
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.9916 - loss: 0.0316
# Testing Accuracy: 99.33%
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step
#                       precision    recall  f1-score   support
#
#      Mild Impairment       0.99      0.99      0.99       314
#  Moderate Impairment       1.00      1.00      1.00        26
#        No Impairment       0.99      1.00      1.00      1120
# Very Mild Impairment       0.99      0.99      0.99       784
#
#             accuracy                           0.99      2244
#            macro avg       0.99      0.99      0.99      2244
#         weighted avg       0.99      0.99      0.99      2244

# %%
# Plot the confusion matrix to understand the classification in detail
test_ls, pred_ls = test_images.classes,pred
conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels=CLASSES, yticklabels=CLASSES)

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
#Printing some other classification metrics
print("Balanced Accuracy Score: {} %".format(round(BAS(test_ls, pred_ls) * 100, 2)))
print("Matthew's Correlation Coefficient: {} %".format(round(MCC(test_ls, pred_ls) * 100, 2)))
# Out:
# Balanced Accuracy Score: 99.41 %
# Matthew's Correlation Coefficient: 98.9 %

# %%
model.save("Alzheimer_diagnosis_cnn_custom_model(99.33%).h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
